# %%
# brevee exposicao de daoos coletados

# %%
#importacao das bibliotecas neceessarias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import statistics as sts
import dataframe_image as dfi

from scipy.stats import wilcoxon

# %% [markdown]
# # ---------- Abrindo arquivo ----------

# %%
arquivo = pd.read_csv("Pesquisa Aviação (respostas) - Respostas ao formulário 1.csv")

#correcao feita para exibir todas as colunas
pd.set_option("display.max_columns", None)  
#exposicao da  primeir linha para entendimento
arquivo.head(1)
# Out:
#   Carimbo de data/hora Termo de Consentimento Livre e Esclarecido-TCLE\n  \
# 0  05/06/2023 22:07:04         Li, e concordo em participar da pesquisa.
#
#                          E-mail  \
# 0  pedrodeoliveira353@gmail.com
#
#   Coloque apenas as iniciais do seu nome (ex: Vanessa de Araújo Carlot = VAC):  \
# 0                                                PAO
#
#   Coloque sua data de nascimento: Qual é o seu gênero? Qual é sua altura?\n  \
# 0                      23/05/1995            Masculino  Entre 1,71m e 1,90m
#
#   Qual é o seu peso? Em qual área da aviação você atua?  \
# 0  Entre 70kg e 90kg                   Instrução de voo
#
#   Qual a frequência dos seus voos? (desconsidere os dias de folga)  \
# 0                Frequência: Mais de uma vez por dia
#
#   Qual a média de duração dos seus voos?  \
# 0    Duração do voo: curta (até 2 horas)
#
#   Há quanto tempo você é piloto? Se não souber, dê uma estimativa.   \
# 0                                   Menos de 5 anos.
#
#   Você repara algum desses sintomas na sua voz? Pode marcar mais de uma opção, e especificar na opção "Outro" caso não tenha listado entre as opções fornecidas.  \
# 0  Falha na voz, Cansaço Vocal, Esforço Vocal, Re...
#
#   Você já recebeu orientações sobre cuidados com a voz?  \
# 0                                                NaN
#
#   Você considera a sua voz essencial para o exercício da profissão?  \
# 0                                                Sim
#
#   Fadiga e restrição vocal [Fico sem vontade de falar depois que falei um pouco mais.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Minha voz fica cansada quando eu falo muito.]  \
# 0                                   3 = quase sempre
#
#   Fadiga e restrição vocal [Sinto que o esforço aumenta enquanto falo.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Minha voz fica rouca depois que falo.]  \
# 0                                    1 = quase nunca
#
#   Fadiga e restrição vocal [Tenho que fazer força para produzir a voz.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Procuro evitar falar depois que usei muito a voz.]  \
# 0                                          0 = nunca
#
#   Fadiga e restrição vocal [Evito situações sociais quando sei que vou ter que falar muito.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Tenho dificuldades para falar com minha família depois de um dia de trabalho.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Tenho que fazer força para produzir a voz depois que falei um pouco mais.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Tenho dificuldade para projetar a minha voz enquanto falo.]  \
# 0                                       2 = às vezes
#
#   Fadiga e restrição vocal [Minha voz fica fraca depois que eu falo um pouco mais.]  \
# 0                                   3 = quase sempre
#
#   Desconforto físico associado à voz [Fico com dor no pescoço ao final do dia quando uso a voz.]  \
# 0                                    1 = quase nunca
#
#   Desconforto físico associado à voz [Fico com dor na garganta ao final do dia quando uso a voz.]  \
# 0                                    1 = quase nunca
#
#   Desconforto físico associado à voz [Quando eu falo muito sinto dor para falar.]  \
# 0                                    1 = quase nunca
#
#   Desconforto físico associado à voz [Quando eu falo minha garganta dói.]  \
# 0                                    1 = quase nunca
#
#   Desconforto físico associado à voz [Quando eu falo sinto desconforto no pescoço.]  \
# 0                                    1 = quase nunca
#
#   Recuperação com repouso vocal [Quando eu descanso minha voz melhora. 0 1 2 3 4]  \
# 0                                   3 = quase sempre
#
#   Recuperação com repouso vocal [Quando eu descanso faço menos força para falar. 0 1 2 3 4]  \
# 0                                         4 = sempre
#
#   Recuperação com repouso vocal [Quando eu descanso minha voz fica menos rouca.]  \
# 0                                   3 = quase sempre
#
#     @  Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38
# 0 NaN          NaN         NaN         NaN         NaN

# %% [markdown]
# # ---------- Tratamento de erros e clareza aos cabeçalhos ----------

# %%
#eeliminando colunas vazias
arquivo = arquivo.drop(columns=["@","Unnamed: 35", "Unnamed: 36", "Unnamed: 37", "Unnamed: 38"], axis=1)

# %%
arquivo.shape
# Out:
# (50, 34)

# %%
# vou simplificar o nome desssas colunas q eestao me deixando confusas 
# para isso vou usar palavras chavees ou expressoees nas peerguntas

novos_nomes = ["data", "termo", "email", "inicias", "nascimento", "genero", "altura","peso", "area_atuacao",
               "freq_voos","media_duracao_voos", "tempo_aviacao", "sintomas", "orientacoes", "importancia_voz",
               
               "restricao_vocal_1", "restricao_vocal_2", "restricao_vocal_3","restricao_vocal_4","restricao_vocal_5",
               "restricao_vocal_6","restricao_vocal_7","restricao_vocal_8", "restricao_vocal_9", "restricao_vocal_10", "restricao_vocal_11",
               
               "desconforto_fisico_1","desconforto_fisico_2","desconforto_fisico_3","desconforto_fisico_4","desconforto_fisico_5",
               
               "recuperacao_vocal_1","recuperacao_vocal_2","recuperacao_vocal_3"] 

arquivo.columns=novos_nomes

# %%
# a principo vamos exibir as MEEDIAS MEDIANAS E DEESVIOS-PADRAO das colunas numericas
#separarei em um novo dataframee (dados_numeericos)e tratarei as respostas q mee pareceem q nao seerao eexibidas numeericameente

dados_numericos = arquivo.loc[:, "restricao_vocal_1":"recuperacao_vocal_3"]

dados_numericos.head()
# Out:
#   restricao_vocal_1 restricao_vocal_2 restricao_vocal_3 restricao_vocal_4  \
# 0      2 = às vezes  3 = quase sempre      2 = às vezes   1 = quase nunca
# 1      2 = às vezes      2 = às vezes      2 = às vezes  3 = quase sempre
# 2  3 = quase sempre      2 = às vezes   1 = quase nunca         0 = nunca
# 3         0 = nunca         0 = nunca         0 = nunca         0 = nunca
# 4         0 = nunca         0 = nunca         0 = nunca         0 = nunca
#
#   restricao_vocal_5 restricao_vocal_6 restricao_vocal_7 restricao_vocal_8  \
# 0      2 = às vezes         0 = nunca      2 = às vezes      2 = às vezes
# 1  3 = quase sempre  3 = quase sempre   1 = quase nunca   1 = quase nunca
# 2   1 = quase nunca  3 = quase sempre   1 = quase nunca      2 = às vezes
# 3         0 = nunca         0 = nunca         0 = nunca         0 = nunca
# 4         0 = nunca         0 = nunca         0 = nunca         0 = nunca
#
#   restricao_vocal_9 restricao_vocal_10 restricao_vocal_11  \
# 0      2 = às vezes       2 = às vezes   3 = quase sempre
# 1      2 = às vezes    1 = quase nunca   3 = quase sempre
# 2         0 = nunca          0 = nunca    1 = quase nunca
# 3         0 = nunca          0 = nunca          0 = nunca
# 4         0 = nunca          0 = nunca          0 = nunca
#
#   desconforto_fisico_1 desconforto_fisico_2 desconforto_fisico_3  \
# 0      1 = quase nunca      1 = quase nunca      1 = quase nunca
# 1         2 = às vezes         2 = às vezes      1 = quase nunca
# 2         2 = às vezes      1 = quase nunca            0 = nunca
# 3            0 = nunca            0 = nunca            0 = nunca
# 4            0 = nunca            0 = nunca            0 = nunca
#
#   desconforto_fisico_4 desconforto_fisico_5 recuperacao_vocal_1  \
# 0      1 = quase nunca      1 = quase nunca    3 = quase sempre
# 1      1 = quase nunca         2 = às vezes    3 = quase sempre
# 2            0 = nunca         2 = às vezes          4 = sempre
# 3            0 = nunca            0 = nunca          4 = sempre
# 4            0 = nunca            0 = nunca     1 = quase nunca
#
#   recuperacao_vocal_2 recuperacao_vocal_3
# 0          4 = sempre    3 = quase sempre
# 1          4 = sempre          4 = sempre
# 2          4 = sempre           0 = nunca
# 3          4 = sempre          4 = sempre
# 4     1 = quase nunca           0 = nunca

# %%
#dados_numericos.median()

#dados_numericos.mean()

#dados_numericos.std()

# %%
#criando um dicionario para substituir os valores q sao strings para numeericos
def valores_inteiros (valor_string):
    if valor_string == "0 = nunca":
        return 0
    elif valor_string == "1 = quase nunca":
        return 1
    elif valor_string == '2 = às vezes':
        return 2
    elif valor_string == "3 = quase sempre":
        return 3
    elif valor_string == "4 = sempre":
        return 4
    elif isinstance(valor_string, int):
        return valor_string
    else:
        return 100000

for coluna in dados_numericos.columns:
    for linha in dados_numericos.index:
        dados_numericos.at[linha,coluna]= valores_inteiros(dados_numericos.at[linha,coluna])

dados_numericos.head()
# Out:
#   restricao_vocal_1 restricao_vocal_2 restricao_vocal_3 restricao_vocal_4  \
# 0                 2                 3                 2                 1
# 1                 2                 2                 2                 3
# 2                 3                 2                 1                 0
# 3                 0                 0                 0                 0
# 4                 0                 0                 0                 0
#
#   restricao_vocal_5 restricao_vocal_6 restricao_vocal_7 restricao_vocal_8  \
# 0                 2                 0                 2                 2
# 1                 3                 3                 1                 1
# 2                 1                 3                 1                 2
# 3                 0                 0                 0                 0
# 4                 0                 0                 0                 0
#
#   restricao_vocal_9 restricao_vocal_10 restricao_vocal_11  \
# 0                 2                  2                  3
# 1                 2                  1                  3
# 2                 0                  0                  1
# 3                 0                  0                  0
# 4                 0                  0                  0
#
#   desconforto_fisico_1 desconforto_fisico_2 desconforto_fisico_3  \
# 0                    1                    1                    1
# 1                    2                    2                    1
# 2                    2                    1                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#   desconforto_fisico_4 desconforto_fisico_5 recuperacao_vocal_1  \
# 0                    1                    1                   3
# 1                    1                    2                   3
# 2                    0                    2                   4
# 3                    0                    0                   4
# 4                    0                    0                   1
#
#   recuperacao_vocal_2 recuperacao_vocal_3
# 0                   4                   3
# 1                   4                   4
# 2                   4                   0
# 3                   4                   4
# 4                   1                   0

# %% [markdown]
# # -------------------- Analisando os dados --------------------

# %%
# media desvio e mediana para os campos unificados de restricao_vocal, desconforto_fisico e recuperacao_vocal

restricao = dados_numericos.loc[:,"restricao_vocal_1":"restricao_vocal_11"].sum(axis=1)
desconforto = dados_numericos.loc[:,"desconforto_fisico_1":"desconforto_fisico_5"].sum(axis=1)
recuperacao = dados_numericos.loc[:,"recuperacao_vocal_1":"recuperacao_vocal_3"].sum(axis=1)
total = dados_numericos.loc[:,"restricao_vocal_1":"recuperacao_vocal_3"].sum(axis=1)
#restricao_media  = restricao.stack().mean()   meeelhor do jeito q fiz embiaxo com numpy
restricao_media, restricao_mediana, restricao_desvio = np.mean(restricao.values), np.median(restricao.values), np.std(restricao.values)
desconforto_media, desconforto_mediana, desconforto_desvio = np.mean(desconforto.values), np.median(desconforto.values), np.std(desconforto.values)
recuperacao_media, recuperacao_mediana, recuperacao_desvio = np.mean(recuperacao.values), np.median(recuperacao.values), np.std(recuperacao.values)
total_media, total_eediana, total_desvio = np.mean(total.values), np.median(total.values), np.std(total.values)
restricao_desvio,desconforto_desvio, recuperacao_desvio, total_desvio= round(restricao_desvio,2), round(desconforto_desvio,2), round(recuperacao_desvio,2), round(total_desvio,2)

print ("RESTRICAO\nMedia=", restricao_media, "\nMediana=", restricao_mediana, "\nDesvio padrao=", restricao_desvio)
print ("\nDESCONFORTO\nMedia=", desconforto_media, "\nMediana=", desconforto_mediana, "\nDesvio padrao=", desconforto_desvio)
print ("\nRECUPERACAO\nMedia=", recuperacao_media, "\nMediana=", recuperacao_mediana, "\nDesvio padrao=", recuperacao_desvio)
print  ("\nTOTAL\nMedia+", total_media, "\nMediana=", total_eediana, "\nDesvio padrao=", total_desvio)
# Out:
# RESTRICAO
# Media= 10.66
# Mediana= 10.5
# Desvio padrao= 8.02
#
# DESCONFORTO
# Media= 1.96
# Mediana= 1.5
# Desvio padrao= 2.14
#
# RECUPERACAO
# Media= 7.84
# Mediana= 8.0
# Desvio padrao= 3.17
#
# TOTAL
# Media+ 20.46
# Mediana= 19.5
# Desvio padrao= 10.56

# %%
# calculando os quartis de .25 e .75 ( 25% e 75% respeectivameente)
restricao_quantis = restricao.quantile([.25,.75])
desconforto_quantis = desconforto.quantile([.25,.75])
recuperacao_quantis = recuperacao.quantile([.25,.75])
total_quqntis= total.quantile([.25,.75])

#restricao_quantis, desconforto_quantis, recuperacao_quantis, total_quqntis

# %%
data = { "Restrição Vocal":[restricao_media, restricao_mediana,restricao_desvio] ,
         "Desconforto Físico":[desconforto_media, desconforto_mediana, desconforto_desvio], 
         "Recuperação vocal":[recuperacao_media, recuperacao_mediana, recuperacao_desvio],
         "Total":[total_media, total_eediana, total_desvio]}
resultados = pd.DataFrame(data,index=["Média","Mediana","Desvio Padrao"]).transpose()
resultados.insert(2,"25%", [restricao_quantis.iloc[0],desconforto_quantis.iloc[0],recuperacao_quantis.iloc[0],total_quqntis.iloc[0]])
resultados.insert(3, "75%", [restricao_quantis.iloc[1],desconforto_quantis.iloc[1],recuperacao_quantis.iloc[1],total_quqntis.iloc[1]])

resultados
# Out:
#                     Média  Mediana    25%   75%  Desvio Padrao
# Restrição Vocal     10.66     10.5   3.25  17.0           8.02
# Desconforto Físico   1.96      1.5   0.00   3.0           2.14
# Recuperação vocal    7.84      8.0   6.00  10.0           3.17
# Total               20.46     19.5  13.00  28.5          10.56

# %%
#salvando a tabela como imagem ee num arquivo .csv
dfi.export(resultados,"resultados/resultados.png")
resultados.to_csv("resultados/resultados.csv",index=False)

# %%
plt.figure(figsize=(7,4))
plt.hist(desconforto, bins=20)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
dados_categoricos = arquivo.loc[:,"data":"importancia_voz"]
dados_categoricos.head(1)
# Out:
#                   data                                      termo  \
# 0  05/06/2023 22:07:04  Li, e concordo em participar da pesquisa.
#
#                           email inicias  nascimento     genero  \
# 0  pedrodeoliveira353@gmail.com     PAO  23/05/1995  Masculino
#
#                 altura               peso      area_atuacao  \
# 0  Entre 1,71m e 1,90m  Entre 70kg e 90kg  Instrução de voo
#
#                              freq_voos                   media_duracao_voos  \
# 0  Frequência: Mais de uma vez por dia  Duração do voo: curta (até 2 horas)
#
#       tempo_aviacao                                           sintomas  \
# 0  Menos de 5 anos.  Falha na voz, Cansaço Vocal, Esforço Vocal, Re...
#
#   orientacoes importancia_voz
# 0         NaN             Sim

# %%
#verificando se existeem campos nao preenchidos
#percebe-se que alguem esqueceu de preencheer vou atribuir a resposta mais comum (Não) para essa orientacao que falta 

dados_categoricos.isnull().sum()
# Out:
# data                  0
# termo                 0
# email                 0
# inicias               0
# nascimento            0
# genero                0
# altura                0
# peso                  0
# area_atuacao          0
# freq_voos             0
# media_duracao_voos    0
# tempo_aviacao         0
# sintomas              0
# orientacoes           1
# importancia_voz       0
# dtype: int64

# %%
dados_categoricos["orientacoes"].fillna("Não", inplace=True)
dados_categoricos.orientacoes.isnull().sum()
# Out:
# 0

# %%
# nalisando as colunas com dados cateegoricos  (nao sao valores numeericos)

genero = dados_categoricos.groupby("genero").size()
genero_p100 = dados_categoricos["genero"].value_counts(normalize=True)*100
altura = dados_categoricos.groupby("altura").size()
altura_p100 = dados_categoricos["altura"].value_counts(normalize=True)*100
peso = dados_categoricos.groupby("peso").size()
peso_p100 = dados_categoricos["peso"].value_counts(normalize=True)*100
area_atuacao = dados_categoricos.groupby("area_atuacao").size()
area_atuacao_p100 = dados_categoricos["area_atuacao"].value_counts(normalize=True)*100
freq_voos = dados_categoricos.groupby("freq_voos").size()
freq_voos_p100 = dados_categoricos["freq_voos"].value_counts(normalize=True)*100
media_duracao_voos = dados_categoricos.groupby("media_duracao_voos").size()
media_duracao_voos_p100 = dados_categoricos["media_duracao_voos"].value_counts(normalize=True)*100
tempo_aviacao = dados_categoricos.groupby("tempo_aviacao").size()
tempo_aviacao_p100 = dados_categoricos["tempo_aviacao"].value_counts(normalize=True)*100
orientacoes = dados_categoricos.groupby("orientacoes").size()
orientacoes_p100 = dados_categoricos["orientacoes"].value_counts(normalize=True)*100
importancia_voz = dados_categoricos.groupby("importancia_voz").size()
importancia_voz_p100 = dados_categoricos["importancia_voz"].value_counts(normalize=True)*100

#acredito quee sintomas vai ter q seer feita uma analisee mais detalhada

# %%
print("Genero (%)"); print(genero_p100.to_string(index=True))
# Out:
# Genero (%)
# Masculino    90.0
# Feminino     10.0

# %%
print("Altura (%)"); print(altura_p100.to_string(index=True))
# Out:
# Altura (%)
# Entre 1,71m e 1,90m    74.0
# Entre 1,51m e 1,70m    24.0
# A partir de 1,91m       2.0

# %%
print("Peso (%):"); print(peso_p100.to_string(index=True))
# Out:
# Peso (%):
# Entre 70kg e 90kg    64.0
# Entre 51kg e 70kg    20.0
# A partir de 91kg     14.0
# Até 50kg              2.0

# %%
print("Area de atuação (%):\n"); print(area_atuacao_p100.to_string(index=True))
# Out:
# Area de atuação (%):
#
# Instrução de voo                       46.0
# Aviação executiva                      20.0
# Táxi aéreo                              8.0
# Aviação militar                         8.0
# Instrução de voo, Aviação executiva     6.0
# Aviação linha aérea                     6.0
# Instrução de voo, Aviação militar       2.0
# Aviação executiva, Aviação militar      2.0
# Táxi aéreo, Aviação linha aérea         2.0

# %%
print("Frequencia de voos (%):\n"); print(freq_voos_p100.to_string(index=True))
# Out:
# Frequencia de voos (%):
#
# Frequência: Ao menos uma vez por semana     38.0
# Frequência: Toda semana (quase todo dia)    28.0
# Frequência: Esporadicamente                 16.0
# Frequência: Todo dia                        10.0
# Frequência: Mais de uma vez por dia          8.0

# %%
print("Méedia de duração dos voos (%):\n"); print(media_duracao_voos_p100.to_string(index=True))
# Out:
# Méedia de duração dos voos (%):
#
# Duração do voo: curta (até 2 horas)        58.0
# Duração de voo: média (de 2 a 4 horas)     34.0
# Duração de voo: longa (4 ou mais horas)     8.0

# %%
print("Tempo de aviação (%):\n"); print(tempo_aviacao_p100.to_string(index=True))
# Out:
# Tempo de aviação (%):
#
# Menos de 5 anos.      48.0
# Entre 5 e 15 anos.    28.0
# Mais de 15 anos.      14.0
# Mais de 30 anos       10.0

# %%
print("Orientações (%):\n"); print(orientacoes_p100.to_string(index=True))
# Out:
# Orientações (%):
#
# Não    96.0
# Sim     4.0

# %%
print("Importância da voz (%):\n"); print(importancia_voz_p100.to_string(index=True))
# Out:
# Importância da voz (%):
#
# Sim    100.0

# %%
#para a vairavel de sintomas tereemos q analisar melhor


#arquivo.groupby("sintomas").size()
